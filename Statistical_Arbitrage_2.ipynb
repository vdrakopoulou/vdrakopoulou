# %% [markdown]
# <a href="https://colab.research.google.com/github/vdrakopoulou/vdrakopoulou/blob/main/Statistical_Arbitrage_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import zipfile
import os

zip_file_path = '/content/drl_stat_arb_replication_updated_2023_2025.zip'
extraction_path = '/content/unzipped_data'

# Create the extraction directory if it doesn't exist
os.makedirs(extraction_path, exist_ok=True)

# Unzip the file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extraction_path)

print(f'File unzipped to: {extraction_path}')

# List the contents of the unzipped directory
print('Contents of unzipped directory:')
for root, dirs, files in os.walk(extraction_path):
    for name in files:
        print(os.path.join(root, name))
    for name in dirs:
        print(os.path.join(root, name))
# Out:
# File unzipped to: /content/unzipped_data
# Contents of unzipped directory:
# /content/unzipped_data/drl_stat_arb_replication_2023_2025
# /content/unzipped_data/drl_stat_arb_replication_2023_2025/CITATION.cff
# /content/unzipped_data/drl_stat_arb_replication_2023_2025/pyproject.toml
# /content/unzipped_data/drl_stat_arb_replication_2023_2025/UPDATED_DATA_NOTES.md
# /content/unzipped_data/drl_stat_arb_replication_2023_2025/LICENSE
# /content/unzipped_data/drl_stat_arb_replication_2023_2025/requirements.txt
# /content/unzipped_data/drl_stat_arb_replication_2023_2025/README.md
# /content/unzipped_data/drl_stat_arb_replication_2023_2025/Makefile
# /content/unzipped_data/drl_stat_arb_replication_2023_2025/scripts
# /content/unzipped_data/drl_stat_arb_replication_2023_2025/models
# /content/unzipped_data/drl_stat_arb_replication_2023_2025/src
# /content/unzipped_data/drl_stat_arb_replication_2023_2025/results
# /content/unzipped_data/drl_stat_arb_replication_2023_2025/data
# ...

# %% [markdown]
# ### Environment Setup and Dependency Installation
#
# First, I will set up a Python virtual environment, upgrade `pip`, and install the dependencies from `requirements.txt`.

# %%
# Removed: Virtual environment creation is often problematic in Colab and not strictly necessary for many tasks.
# !python -m venv .venv

# %%
# Removed: Activating a virtual environment doesn't persist across cells in Colab as it does in a typical shell.
# !source .venv/bin/activate

# %%
# !python -m pip install -U pip
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 7.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...

# %%
PROJECT_ROOT = '/content/unzipped_data/drl_stat_arb_replication_2023_2025'
# %cd {PROJECT_ROOT}
# !pip install -r requirements.txt
# Out:
# /content/unzipped_data/drl_stat_arb_replication_2023_2025
# ...

# %%
PROJECT_ROOT = '/content/unzipped_data/drl_stat_arb_replication_2023_2025'
# %cd {PROJECT_ROOT}
# !pip install -e .
# Out:
# /content/unzipped_data/drl_stat_arb_replication_2023_2025
# Obtaining file:///content/unzipped_data/drl_stat_arb_replication_2023_2025
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for drl-stat-arb-replication (pyproject.toml) ... done
#   Created wheel for drl-stat-arb-replication: filename=drl_stat_arb_replication-0.1.0-0.editable-py3-none-any.whl size=5645 sha256=3d867dd52ca319b95a6920810bc9b38379e5b4bbb0f1caab6b7f2d12348434b5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ar0_h8ih/wheels/1e/1f/3b/fd5702057d48fd96d99a10df0a447b6d98f5ceb973bdddae24
# Successfully built drl-stat-arb-replication
# ...

# %% [markdown]
# ### Running Tests and Scripts
#
# Now, I will run the smoke test and then execute all the scripts using the provided configuration.

# %%
PROJECT_ROOT = '/content/unzipped_data/drl_stat_arb_replication_2023_2025'
# %cd {PROJECT_ROOT}
# !python scripts/smoke_test.py
# Out:
# /content/unzipped_data/drl_stat_arb_replication_2023_2025
#           mean       std      min       50%  ...    VaR 5%    ES 5%      skew  kurt
# COIN  0.144345  0.047231  0.10788  0.127457  ...  0.109838  0.10788  1.403333  -1.5
#
# [1 rows x 9 columns]
#       MDD%    ES 5%    VaR 5%    sigma%  AS  Calmar    Sharpe  EPM        R%
# COIN   0.0  0.10788  0.109838  0.047231 NaN     NaN  3.056138  NaN  0.433639
# Smoke test passed

# %%
PROJECT_ROOT = '/content/unzipped_data/drl_stat_arb_replication_2023_2025'
# %cd {PROJECT_ROOT}
# !bash scripts/run_all.sh configs/updated_2023_2025.yaml
# Out:
# Streaming output truncated to the last 5000 lines.
# | train/                |           |
# |    entropy_loss       | -2.24e-05 |
# |    explained_variance | -8.89     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 197089    |
# |    policy_loss        | -1.69e-09 |
# |    value_loss         | 1.72e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | 0.00114   |
# | time/                 |           |
# |    fps                | 265       |
# |    iterations         | 197100    |
# |    time_elapsed       | 3716      |
# |    total_timesteps    | 985500    |
# | train/                |           |
# |    entropy_loss       | -1.74e-05 |
# |    explained_variance | 0.598     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 197099    |
# |    policy_loss        | -2.04e-09 |
# ...

# %%
PROJECT_ROOT = '/content/unzipped_data/drl_stat_arb_replication_2023_2025'
# %cd {PROJECT_ROOT}

print('Contents of models directory:')
# !ls -lh models || true

print('\nContents of results directory:')
# !ls -lh results || true

print('\nContents of figures directory:')
# !ls -lh figures || true
# Out:
# /content/unzipped_data/drl_stat_arb_replication_2023_2025
# Contents of models directory:
# total 532K
# -rw-r--r-- 1 root root 122K Jun  4 10:22 A2C.zip
# -rw-r--r-- 1 root root 121K Jun  4 09:19 DQN.zip
# -rw-r--r-- 1 root root 105K Jun  4 10:34 LSTM.pt
# -rw-r--r-- 1 root root 172K Jun  4 08:27 PPO.zip
# -rw-r--r-- 1 root root 2.0K Jun  4 10:28 SVM.joblib
#
# Contents of results directory:
# total 14M
# -rw-r--r-- 1 root root  26K Jun  4 10:35 daily_returns_costs.csv
# -rw-r--r-- 1 root root  36K Jun  4 10:35 daily_returns.csv
# -rw-r--r-- 1 root root 1.3M Jun  4 10:35 intraday_returns_costs.csv
# -rw-r--r-- 1 root root 1.7M Jun  4 10:35 intraday_returns.csv
# -rw-r--r-- 1 root root 5.3M Jun  4 10:35 policy_trace_costs.csv
# -rw-r--r-- 1 root root 5.3M Jun  4 10:35 policy_trace.csv
# -rw-r--r-- 1 root root  708 Jun  4 10:36 REPORT.md
# -rw-r--r-- 1 root root  464 Jun  4 10:35 table_daily_annualized.csv
# -rw-r--r-- 1 root root  358 Jun  4 10:35 table_daily_costs_annualized.csv
# ...

# %%
PROJECT_ROOT = '/content/unzipped_data/drl_stat_arb_replication_2023_2025'
# %cd {PROJECT_ROOT}
# !cat results/REPORT.md
# Out:
# /content/unzipped_data/drl_stat_arb_replication_2023_2025
# # Replication output report
#
# - `daily_returns.csv`
# - `daily_returns_costs.csv`
# - `intraday_returns.csv`
# - `intraday_returns_costs.csv`
# - `policy_trace.csv`
# - `policy_trace_costs.csv`
# - `table_daily_annualized.csv`
# - `table_daily_costs_annualized.csv`
# - `table_daily_costs_risk_performance.csv`
# - `table_daily_costs_summary.csv`
# - `table_daily_risk_performance.csv`
# - `table_daily_summary.csv`
# - `table_intraday_annualized.csv`
# - `table_intraday_costs_annualized.csv`
# - `table_intraday_costs_risk_performance.csv`
# - `table_intraday_costs_summary.csv`
# - `table_intraday_risk_performance.csv`
# - `table_intraday_summary.csv`
# - `figures/pnl_daily.png`
# - `figures/pnl_daily_costs.png`
# - `figures/pnl_intraday.png`
