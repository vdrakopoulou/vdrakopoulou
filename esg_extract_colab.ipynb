# %% [markdown]
# <a href="https://colab.research.google.com/github/vdrakopoulou/vdrakopoulou/blob/main/esg_extract_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1) Install dependency
# !pip install PyPDF2

# 2) Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 3) Imports and path setup
from pathlib import Path
import csv
import re
from PyPDF2 import PdfReader
# Out:
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 9.6 MB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1
# Mounted at /content/drive

# %%
# >>> CHANGE THESE ONLY IF YOUR FOLDER NAMES ARE DIFFERENT <<<
REPORTS_DIR = Path("/content/drive/MyDrive/adx_ESG_reports")
OUTPUT_CSV = Path("/content/drive/MyDrive/data/raw/esg_messages_raw.csv")

# 4) ESG keyword lists
E_KEYWORDS = [
    "environment", "environmental", "emissions", "carbon", "co2", "ghg",
    "greenhouse gas", "climate", "renewable", "energy efficiency",
    "biodiversity", "waste", "recycling", "water usage", "water use",
    "pollution", "sustainable", "sustainability", "net zero", "decarbonization"
]

S_KEYWORDS = [
    "social", "community", "human rights", "labor", "labour", "workplace",
    "health and safety", "occupational safety", "safety incident",
    "diversity", "equity", "inclusion", "dei", "employee engagement",
    "training hours", "fair wage", "child labor", "forced labor",
    "local communities", "stakeholder", "philanthropy", "donation"
]

G_KEYWORDS = [
    "governance", "board of directors", "board", "audit committee",
    "remuneration committee", "compensation committee", "ethics",
    "code of conduct", "anti-corruption", "anticorruption", "anti bribery",
    "whistleblowing", "whistle-blowing", "compliance", "risk management",
    "internal control", "shareholder rights", "transparency"
]

ALL_KEYWORDS = [kw.lower() for kw in (E_KEYWORDS + S_KEYWORDS + G_KEYWORDS)]

# %%
from pathlib import Path

esg_reports_path = Path('/content/drive/MyDrive/adx_ESG_reports')

if esg_reports_path.exists() and esg_reports_path.is_dir():
    print(f"Listing contents of {esg_reports_path}:")
    for item in esg_reports_path.iterdir():
        print(f"- {item.name}{'/' if item.is_dir() else ''}")
else:
    print(f"Error: {esg_reports_path} does not exist or is not a directory.")
# Out:
# Listing contents of /content/drive/MyDrive/adx_ESG_reports:
# - ADNOC.pdf
# - ADNOC Distribution ESG Report 2024-English-F.pdf
# - BILDCO.pdf
# - ADNOC_LS Sustainability Report 2024 English.pdf
# - ADPORTS_Sustainability-Report-2024.pdf
# - KICO_SUSTAINABILITY_REPORT_2024.pdf
# - APEX.pdf
# - ADCB 2024.pdf
# - ADIB ESG report 2023.pdf
# - Abu Dhabi Aviation Sustainability-Report-2024-English.pdf
# - TAQA Announces 2030 Emissions Reductions Targets as part of New ESG Strategy (English) 13.10.22.pdf
# - ADNH 2024.pdf
# - ADNIC 2022.pdf
# - ADNOC DISTRIBUTION 2024.pdf
# - ADIB Sustainability Report 2024 EN (1).pdf
# - TKFL_Sustainability_Report_EN_2024.pdf
# - ADSB_sustainability_Report_2023.pdf
# - ALAIN.pdf
# - ADNIC_sustainability-report-english-2023.pdf
# - DAFRA_ADIC_Sustainability_ESG_Report_2024_Eng.pdf
# - AFNIC 2021_Integrated Report.pdf
# - AKIC_Al-Khayyat-Investments-Sustainability-Report-2024.pdf
# - ASM_2024-esg-supplement-2.pdf
# - AWNIC_2022.pdf
# - YAHSAT_ESG Policy 23rd Aug 2023.pdf
# - ALPHADHABI_sustainability_report_2024.pdf
# - AMR Corporate Sustainability.pdf
# - aramex-sustainability-annual-report.pdf
# - BOS-ESG-Report-2024.pdf
# - Borouge Sustainability Report 2023.pdf
# - cbi-sustainability-report-2024_eng.pdf
# - DANA_2024-Sustainability-Report.pdf
# - FNF_2024.pdf
# - GUITHA_2023.pdf
# - DRIVE_2024.pdf
# - E7_integrated-report-2024.pdf
# - EAND_2024.pdf
# - EASYLEASE_2023.pdf
# - EIC_2024.pdf
# - FAB-ESG-Report-2024.pdf
# - EMSTEEL_Sustainability-Report_2024.pdf
# - ESG_2024.pdf
# - ESHRAQ_2024.pdf
# - FBI_2024.pdf
# - FCI_2023.pdf
# - Fertiglobe-AR2023-E-vF-Sustainability.pdf
# - FH_2023.pdf
# - FIDELITYUNITED_2023.pdf
# - GCEM_Integrated-Report_2024.pdf
# - GIH_2024.pdf
# - RAK_ESG-Report-2024.pdf
# - GMPC_INTEGRATED_ANNUAL_REPORT_2024.pdf
# - hayah-_sustainability-report-2023_eng.pdf
# - hh_sustainabilty_report_2023.pdf
# - INVICTUS_ESG_2024.pdf
# - Investcorp_Sustainability_Report_2024.pdf
# - IHC_2024.pdf
# - INVESTB_Sustainability Report_2024.pdf
# - JULPHAR_ESG_2024.pdf
# - METHAQ_Sustanability-Report-2021.pdf
# - MULTIPLY_ESG_2024.pdf
# - NBF_Sustainability-Report-2024.pdf
# - NBQ_INTEGRATED_REPORT_2024.pdf
# - NCTH-2024-Financial-Statements.pdf
# - OEIHC_consolidated_financial_statements_2025.pdf
# - Ooredoo QPSC - 2024 - Annual Report (SustainabilityReports.com).pdf
# - Palms_fs_2025.pdf
# - Phoenix Group PLC - 2024 - ESG Report (SustainabilityReports.com).pdf
# - Presight AI Holding PLC - 2024 - Annual Report (SustainabilityReports.com).pdf
# - Pure Health Holding PJSC - 2024 - Annual Report and Accounts (SustainabilityReports.com).pdf
# - QIC_Sustainability-Report-2024.pdf
# - RAKBANK_Social_Bond_report_2025.pdf
# - RAKNIC_SUSTAINABILITY_2023.pdf
# - RAKPROP_Sustainability Report 2023.pdf
# - Ras Al Khaimah Co for White Cement & Construction Materials PSC - 2022 - Sustainability Report (SustainabilityReports.com).pdf
# - RPM_FY2024-Consolidated-Audited-Finanacial-Statements.pdf
# - Sawaeed_Holding-_Corporate_governance_English_2024.pdf
# - SCIDC_SUSTAINABILITY_REPORT_2022.pdf
# - SIB_ESG_2024.pdf
# - SICO_SUSTAINABILITY_2024.pdf
# - SUDATEL_REPORT.pdf
# - TNI_CONSOLIDATED_FINANCIAL_STATEMENTS_2025.pdf
# - 2POINTZERO_ESG_Report_English_2024.pdf
# - UAB ESG 2023-En-Final-Website.pdf
# - UNION_2024.pdf
# - WAHA_SUSTAINABILITY_2024.pdf
# - ADNOC Drilling Annual Report 2024.pdf
# - ADNOCGAS_Sustainability_Report_2024.pdf
# - Agility-Global-Sustainability-Report_Restated_July-17-2025_EN.pdf
# - AGTHIA_MD&A_2025.pdf
# - Alef_Education_Integrated_Annual_Report_2024.pdf
# - Alpha Data PJSC - Financials 12-2025.pdf
# - lulu-retail-2024-esg-report.pdf
# - MAIR_Group_Integrated_Report_FY_December_31_2024.pdf
# - MODON_responsible-business-report_2024.pdf
# - NMDC Energy PJSC Sustainability Report_2024.pdf
# - RAPCO Investment PJSC Integrated Report December 31,2024.pdf
# - Space42-Sustainability Report 2024 -.pdf

# %%
import pandas as pd

df_esg_sentences = pd.read_csv(OUTPUT_CSV)

print(f"Total ESG sentences loaded into DataFrame: {len(df_esg_sentences)}")
display(df_esg_sentences.head())

# %%
# 6) Main extraction logic
OUTPUT_CSV.parent.mkdir(parents=True, exist_ok=True)
file_exists = OUTPUT_CSV.exists()
total_pdfs = 0
total_sentences = 0

with OUTPUT_CSV.open("a", newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)

    # Write header only if file doesn't exist yet
    if not file_exists:
        writer.writerow(["source_file", "sentence"])

    pdf_files = sorted(REPORTS_DIR.glob("*.pdf"))
    print(f"Found {len(pdf_files)} PDF files in {REPORTS_DIR}")

    for pdf_path in pdf_files:
        total_pdfs += 1
        print(f"Processing: {pdf_path.name}")
        esg_sentences = extract_esg_sentences_from_pdf(pdf_path)
        print(f"  -> Found {len(esg_sentences)} ESG-related sentences")
        total_sentences += len(esg_sentences)
        for sent in esg_sentences:
            writer.writerow([pdf_path.name, sent])

print("\nDone!")
print(f"Processed PDFs: {total_pdfs}")
print(f"Total ESG sentences extracted: {total_sentences}")
print(f"CSV saved to: {OUTPUT_CSV}")
# Out:
# Found 98 PDF files in /content/drive/MyDrive/adx_ESG_reports
# Processing: 2POINTZERO_ESG_Report_English_2024.pdf
#   -> Found 407 ESG-related sentences
# Processing: ADCB 2024.pdf
#   -> Found 705 ESG-related sentences
# Processing: ADIB ESG report 2023.pdf
#   -> Found 503 ESG-related sentences
# Processing: ADIB Sustainability Report 2024 EN (1).pdf
#   -> Found 751 ESG-related sentences
# Processing: ADNH 2024.pdf
#   -> Found 186 ESG-related sentences
# Processing: ADNIC 2022.pdf
#   -> Found 163 ESG-related sentences
# Processing: ADNIC_sustainability-report-english-2023.pdf
#   -> Found 280 ESG-related sentences
# Processing: ADNOC DISTRIBUTION 2024.pdf
#   -> Found 612 ESG-related sentences
# Processing: ADNOC Distribution ESG Report 2024-English-F.pdf
#   -> Found 612 ESG-related sentences
# Processing: ADNOC Drilling Annual Report 2024.pdf
#   -> Found 763 ESG-related sentences
# Processing: ADNOC.pdf
#   -> Found 13 ESG-related sentences
# Processing: ADNOCGAS_Sustainability_Report_2024.pdf
#   -> Found 1524 ESG-related sentences
# Processing: ADNOC_LS Sustainability Report 2024 English.pdf
#   -> Found 424 ESG-related sentences
# Processing: ADPORTS_Sustainability-Report-2024.pdf
#   -> Found 490 ESG-related sentences
# Processing: ADSB_sustainability_Report_2023.pdf
#   -> Found 204 ESG-related sentences
# Processing: AFNIC 2021_Integrated Report.pdf
#   -> Found 171 ESG-related sentences
# Processing: AGTHIA_MD&A_2025.pdf
#   -> Found 780 ESG-related sentences
# Processing: AKIC_Al-Khayyat-Investments-Sustainability-Report-2024.pdf
#   -> Found 240 ESG-related sentences
# Processing: ALAIN.pdf
#   -> Found 47 ESG-related sentences
# Processing: ALPHADHABI_sustainability_report_2024.pdf
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(152, 0, 132523756148048)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(158, 0, 132523756148048)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(164, 0, 132523756148048)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(170, 0, 132523756148048)]
#   -> Found 231 ESG-related sentences
# Processing: AMR Corporate Sustainability.pdf
#   -> Found 42 ESG-related sentences
# Processing: APEX.pdf
#   -> Found 0 ESG-related sentences
# Processing: ASM_2024-esg-supplement-2.pdf
#   -> Found 113 ESG-related sentences
# Processing: AWNIC_2022.pdf
#   -> Found 184 ESG-related sentences
# Processing: Abu Dhabi Aviation Sustainability-Report-2024-English.pdf
#   -> Found 230 ESG-related sentences
# Processing: Agility-Global-Sustainability-Report_Restated_July-17-2025_EN.pdf
#   -> Found 389 ESG-related sentences
# Processing: Alef_Education_Integrated_Annual_Report_2024.pdf
#   -> Found 255 ESG-related sentences
# Processing: Alpha Data PJSC - Financials 12-2025.pdf
#   -> Found 46 ESG-related sentences
# Processing: BILDCO.pdf
#   -> Found 132 ESG-related sentences
# Processing: BOS-ESG-Report-2024.pdf
#   -> Found 237 ESG-related sentences
# Processing: Borouge Sustainability Report 2023.pdf
#   -> Found 584 ESG-related sentences
# Processing: DAFRA_ADIC_Sustainability_ESG_Report_2024_Eng.pdf
#   -> Found 167 ESG-related sentences
# Processing: DANA_2024-Sustainability-Report.pdf
#   -> Found 42 ESG-related sentences
# Processing: DRIVE_2024.pdf
#   -> Found 443 ESG-related sentences
# Processing: E7_integrated-report-2024.pdf
#   -> Found 618 ESG-related sentences
# Processing: EAND_2024.pdf
#   -> Found 661 ESG-related sentences
# Processing: EASYLEASE_2023.pdf
#   -> Found 182 ESG-related sentences
# Processing: EIC_2024.pdf
#   -> Found 101 ESG-related sentences
# Processing: EMSTEEL_Sustainability-Report_2024.pdf
#   -> Found 672 ESG-related sentences
# Processing: ESG_2024.pdf
#   -> Found 321 ESG-related sentences
# Processing: ESHRAQ_2024.pdf
#   -> Found 128 ESG-related sentences
# Processing: FAB-ESG-Report-2024.pdf
#   -> Found 705 ESG-related sentences
# Processing: FBI_2024.pdf
#   -> Found 0 ESG-related sentences
# Processing: FCI_2023.pdf
#   -> Found 135 ESG-related sentences
# Processing: FH_2023.pdf
#   -> Found 148 ESG-related sentences
# Processing: FIDELITYUNITED_2023.pdf
#   -> Found 121 ESG-related sentences
# Processing: FNF_2024.pdf
#   -> Found 313 ESG-related sentences
# Processing: Fertiglobe-AR2023-E-vF-Sustainability.pdf
#   -> Found 368 ESG-related sentences
# Processing: GCEM_Integrated-Report_2024.pdf
#   -> Found 280 ESG-related sentences
# Processing: GIH_2024.pdf
#   -> Found 17 ESG-related sentences
# Processing: GMPC_INTEGRATED_ANNUAL_REPORT_2024.pdf
#   -> Found 0 ESG-related sentences
# Processing: GUITHA_2023.pdf
#   -> Found 0 ESG-related sentences
# Processing: IHC_2024.pdf
#   -> Found 378 ESG-related sentences
# Processing: INVESTB_Sustainability Report_2024.pdf
#   -> Found 23 ESG-related sentences
# Processing: INVICTUS_ESG_2024.pdf
#   -> Found 178 ESG-related sentences
# Processing: Investcorp_Sustainability_Report_2024.pdf
#   -> Found 236 ESG-related sentences
# Processing: JULPHAR_ESG_2024.pdf
#   -> Found 387 ESG-related sentences
# Processing: KICO_SUSTAINABILITY_REPORT_2024.pdf
#   -> Found 78 ESG-related sentences
# Processing: MAIR_Group_Integrated_Report_FY_December_31_2024.pdf
#   -> Found 399 ESG-related sentences
# Processing: METHAQ_Sustanability-Report-2021.pdf
#   -> Found 0 ESG-related sentences
# Processing: MODON_responsible-business-report_2024.pdf
#   -> Found 455 ESG-related sentences
# Processing: MULTIPLY_ESG_2024.pdf
#   -> Found 407 ESG-related sentences
# Processing: NBF_Sustainability-Report-2024.pdf
#   -> Found 238 ESG-related sentences
# Processing: NBQ_INTEGRATED_REPORT_2024.pdf
#   -> Found 831 ESG-related sentences
# Processing: NCTH-2024-Financial-Statements.pdf
#   -> Found 66 ESG-related sentences
# Processing: NMDC Energy PJSC Sustainability Report_2024.pdf
#   -> Found 42 ESG-related sentences
# Processing: OEIHC_consolidated_financial_statements_2025.pdf
#   -> Found 18 ESG-related sentences
# Processing: Ooredoo QPSC - 2024 - Annual Report (SustainabilityReports.com).pdf
#   -> Found 663 ESG-related sentences
# Processing: Palms_fs_2025.pdf
#   -> Found 0 ESG-related sentences
# Processing: Phoenix Group PLC - 2024 - ESG Report (SustainabilityReports.com).pdf
#   -> Found 73 ESG-related sentences
# Processing: Presight AI Holding PLC - 2024 - Annual Report (SustainabilityReports.com).pdf
#   -> Found 123 ESG-related sentences
# Processing: Pure Health Holding PJSC - 2024 - Annual Report and Accounts (SustainabilityReports.com).pdf
#   -> Found 494 ESG-related sentences
# Processing: QIC_Sustainability-Report-2024.pdf
#   -> Found 48 ESG-related sentences
# Processing: RAKBANK_Social_Bond_report_2025.pdf
#   -> Found 48 ESG-related sentences
# Processing: RAKNIC_SUSTAINABILITY_2023.pdf
#   -> Found 64 ESG-related sentences
# Processing: RAKPROP_Sustainability Report 2023.pdf
#   -> Found 286 ESG-related sentences
# Processing: RAK_ESG-Report-2024.pdf
#   -> Found 528 ESG-related sentences
# Processing: RAPCO Investment PJSC Integrated Report December 31,2024.pdf
#   -> Found 282 ESG-related sentences
# Processing: RPM_FY2024-Consolidated-Audited-Finanacial-Statements.pdf
#   -> Found 0 ESG-related sentences
# Processing: Ras Al Khaimah Co for White Cement & Construction Materials PSC - 2022 - Sustainability Report (SustainabilityReports.com).pdf
#   -> Found 67 ESG-related sentences
# Processing: SCIDC_SUSTAINABILITY_REPORT_2022.pdf
#   -> Found 165 ESG-related sentences
# Processing: SIB_ESG_2024.pdf
#   -> Found 0 ESG-related sentences
# Processing: SICO_SUSTAINABILITY_2024.pdf
#   -> Found 0 ESG-related sentences
# Processing: SUDATEL_REPORT.pdf
#   -> Found 1 ESG-related sentences
# Processing: Sawaeed_Holding-_Corporate_governance_English_2024.pdf
#   -> Found 189 ESG-related sentences
# Processing: Space42-Sustainability Report 2024 -.pdf
#   -> Found 402 ESG-related sentences
# Processing: TAQA Announces 2030 Emissions Reductions Targets as part of New ESG Strategy (English) 13.10.22.pdf
#   -> Found 21 ESG-related sentences
# Processing: TKFL_Sustainability_Report_EN_2024.pdf
#   -> Found 502 ESG-related sentences
# Processing: TNI_CONSOLIDATED_FINANCIAL_STATEMENTS_2025.pdf
#   -> Found 19 ESG-related sentences
# Processing: UAB ESG 2023-En-Final-Website.pdf
#   -> Found 180 ESG-related sentences
# Processing: UNION_2024.pdf
#   -> Found 60 ESG-related sentences
# Processing: WAHA_SUSTAINABILITY_2024.pdf
#   -> Found 123 ESG-related sentences
# Processing: YAHSAT_ESG Policy 23rd Aug 2023.pdf
#   -> Found 105 ESG-related sentences
# Processing: aramex-sustainability-annual-report.pdf
#   -> Found 80 ESG-related sentences
# Processing: cbi-sustainability-report-2024_eng.pdf
#   -> Found 296 ESG-related sentences
# Processing: hayah-_sustainability-report-2023_eng.pdf
#   -> Found 54 ESG-related sentences
# Processing: hh_sustainabilty_report_2023.pdf
#   -> Found 347 ESG-related sentences
# Processing: lulu-retail-2024-esg-report.pdf
#   -> Found 359 ESG-related sentences
#
# Done!
# Processed PDFs: 98
# Total ESG sentences extracted: 26055
# CSV saved to: /content/drive/MyDrive/data/raw/esg_messages_raw.csv

# %%
# 5) Helper functions
def extract_text_from_pdf(pdf_path: Path) -> str:
    """Extract all text from a PDF file."""
    reader = PdfReader(str(pdf_path))
    texts = []
    for page in reader.pages:
        try:
            page_text = page.extract_text() or ""
        except Exception:
            page_text = ""
        texts.append(page_text)
    return "\n".join(texts)


def split_into_sentences(text: str):
    """Rough sentence splitter using punctuation."""
    text = re.sub(r"\s+", " ", text)  # normalize whitespace
    sentences = re.split(r"(?<=[.!?])\s+", text)
    return [s.strip() for s in sentences if len(s.strip()) > 20]


def is_esg_sentence(sentence: str) -> bool:
    """Check if a sentence contains any ESG-related keyword."""
    s_lower = sentence.lower()
    return any(kw in s_lower for kw in ALL_KEYWORDS)


def extract_esg_sentences_from_pdf(pdf_path: Path):
    full_text = extract_text_from_pdf(pdf_path)
    sentences = split_into_sentences(full_text)
    return [s for s in sentences if is_esg_sentence(s)]

# %%
from pathlib import Path

drive_path = Path('/content/drive/MyDrive')

if drive_path.exists():
    print(f"Listing contents of {drive_path}:")
    for item in drive_path.iterdir():
        print(f"- {item.name}{'/' if item.is_dir() else ''}")
else:
    print(f"Error: {drive_path} does not exist. Please ensure Google Drive is mounted correctly.")
# Out:
# Listing contents of /content/drive/MyDrive:
# - RESUME.zip
# - Curriculum Vitae Drakopoulou 2023.docx
# - RESUME2024.zip
# - Violet's Publications.zip
# - ACC4113 Case Study/
# - Colab Notebooks/
# - Copy of ORM_Book_Proposal.gdoc
# - Copy of On-Demand Course Proposal Template (Make a Copy).gdoc
# - RQ2 – AI Literacy and Metacognition: ChatGPT Survey  (File responses)/
# - RQ2 – AI Literacy and Metacognition: ChatGPT Survey .gform
# - RQ2-AI Literacy and Metacognition: ChatGPT Survey/
# - adx_ESG_reports/
